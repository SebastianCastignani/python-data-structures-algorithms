# %% [markdown]
# # ![alt text](https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/50px-Python-logo-notext.svg.png) **Trabajo Práctico 5: Pilas y colas (dinámicas)** ![alt text](https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/50px-Python-logo-notext.svg.png)
#
# En este trabajo práctico, vamos a trabajar con las estructuras de datos **Pila** y **Cola** dinámicas en Python. Recuerden crear una copia de este archivo en su ***Google Drive*** para tener permisos de edición.
#
# ### **florencia.dias@unahur.edu.ar** ###

# %% [markdown]
# Declaración de listas e inserción de elementos

# %%
l1 = [] #list()
print(l1)
l1.append(3);l1.append(4);l1.append(7);l1.append(5);l1.append(2);
print(l1)

l1.insert(0,10) # posicion y dato a insertar
print(l1)

l1.pop() #elimina el ultimo
print(l1)

l1.pop(2) #con argumento, por posicion
print(l1)
# Out:
# []
# [3, 4, 7, 5, 2]
# [10, 3, 4, 7, 5, 2]
# [10, 3, 4, 7, 5]
# [10, 3, 7, 5]

# %% [markdown]
# Acceso por índices

# %%
print(l1)
print(l1[0]) # primer elemento
print(l1[len(l1)-1]) # ultimo elemento
# Out:
# [10, 3, 7, 5, 2]
# 10
# 2

# %% [markdown]
# Recorrido por elementos y por índices

# %%
for elemento in l1:
  print(elemento)

print()

for pos in range(len(l1)):
  print(l1[pos])
# Out:
# 10
# 3
# 7
# 5
# 2
#
# 10
# 3
# 7
# 5
# 2

# %% [markdown]
# ## **Parte 1: Pilas dinámicas**

# %% [markdown]
# ### **Ejercicio 1**
#
# Implementar el TDA Pila (Stack), con las siguientes operaciones:
# - Crear (__init__())
# - Vaciar
# - Apilar elemento (push)
# - Desapilar elemento (pop)
# - Obtener primer elemento (top)
# - Obtener tamaño de pila
# - Clonar
# - Esta vacía.
# - __repr__(). Para poder imprimir una Pila por consola

# %%
import copy as cp # paquete para no tener problemas con las estructuras que tienen multiples niveles

class Pila:
  def __init__(self, listaInicial=None):
    self.pila = []
    if listaInicial:
      self.pila = cp.deepcopy(listaInicial)

  def tamanio(self)->int:
    return len(self.pila)

  def estaVacia(self)->bool:
    return self.tamanio() == 0

  def apilar(self, dato:int)->None:
    self.pila.append(dato)

  def tope(self)->int:
    datoCima = None
    if not self.estaVacia():
      datoCima = self.pila[len(self.pila)-1] # leo ultimo elemento
    return datoCima

  def desapilar(self)->int:
    dato = None
    if not self.estaVacia():
      dato = self.pila.pop()
    return dato

  def vaciar(self)->None:
    self.pila = []

  def clonar(self): # retorna una pila que contengan los mismos elementos pero en otra posicion de memoria
    return cp.deepcopy(self)

  def __repr__(self)->str:
    return str(self.pila)+"<->"

# %%
pila1 = Pila()
print(pila1)
pila1.apilar(3);pila1.apilar(2);pila1.apilar(7);pila1.apilar(4)
print(pila1)
print(pila1.tope())
print(pila1.desapilar())
print(pila1)
print(pila1.tope())
pila2 = pila1.clonar()
print("pila2",pila2)
# Out:
# []<->
# [3, 2, 7, 4]<->
# 4
# 4
# [3, 2, 7]<->
# 7
# pila2 [3, 2, 7]<->

# %%
print(pila1)
while not pila1.estaVacia(): #iteramos una pila
  print(pila1.desapilar())
print(pila1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6606dd76213e> in <cell line: 0>()
# ----> 1 print(pila1)
#       2 while not pila1.estaVacia(): #iteramos una pila
#       3   print(pila1.desapilar())
#       4 print(pila1)
#
# NameError: name 'pila1' is not defined

# %% [markdown]
# ### A partir del **Ejercicio 2** vamos a trabajar fuera del TDA Pila usando la interface que creamos en el **Ejercicio 1**. Es decir, se pueden usar solo las operaciones de la interface, no se puede acceder a los componentes internos del TDA. Si necesitan estructuras auxiliares, pueden usar otra pila, arreglos o listas.

# %% [markdown]
# ### **Ejercicio 2**
#
# Escribir un programa que declare una pila de enteros y le apile 4 elementos. Luego debe mostrar la pila y su tamaño, desapilar 2 elementos y volver a imprimirla junto con el nuevo tamaño.

# %%
pilaEntero = Pila()
pilaEntero.apilar(1)
pilaEntero.apilar(2)
pilaEntero.apilar(3)
pilaEntero.apilar(4)


print(pilaEntero)
print(pilaEntero.tamanio())

pilaEntero.desapilar()
pilaEntero.desapilar()

print(pilaEntero)

print(pilaEntero.tamanio())
# Out:
# [1, 2, 3, 4]<->
# 4
# [1, 2]<->
# 2

# %% [markdown]
# ### **Ejercicio 3**
#
# Escribir una función que invierta el orden de una pila. No debe devolver una nueva pila invertida, sino invertir la pila que ingresa por parámetro.

# %%
def invertirPila(pila):
  pilaAux = pila.clonar()
  pila.vaciar()
  while not pilaAux.estaVacia():
        pila.apilar(pilaAux.desapilar())
  return pila


pilaEntero = Pila()
pilaEntero.apilar(1)
pilaEntero.apilar(2)
pilaEntero.apilar(3)
pilaEntero.apilar(4)

print(invertirPila(pilaEntero))
# Out:
# [4, 3, 2, 1]<->

# %% [markdown]
# ### **Ejercicio 4**
#
# Escribir una función que toma el último elemento de una pila(la base) y lo ponga en la cima (de la misma pila), respetando el orden del resto de los elementos. Utilizar una pila auxiliar.

# %%
def ponerUltimoElementoEnLaPila(pila):
  #pila_Auxiliar = pila.clonar()
  invertirPila(pila)
  elemento = pila.desapilar()
  invertirPila(pila)
 # invertirPila(pila_Auxiliar)
  pila.apilar(elemento)
  return pila

pilaPrueba = Pila()
pilaPrueba.apilar(1)
pilaPrueba.apilar(2)
pilaPrueba.apilar(3)
pilaPrueba.apilar(4)

print(pilaPrueba)


ponerUltimoElementoEnLaPila(pilaPrueba)
# Out:
# [1, 2, 3, 4]<->
# [2, 3, 4, 1]<->

# %% [markdown]
# ### **Ejercicio 5**
#
# Escribir una función que coloque en el fondo de una pila un nuevo elemento.

# %%
def colocarAlFondoDeUnaPila(pila : Pila ,objeto:int):
  invertirPila(pila)
  pila.apilar(objeto)
  invertirPila(pila)
  return pila

pila5 = Pila()
pila5.apilar(1)
pila5.apilar(2)
pila5.apilar(3)
pila5.apilar(4)

colocarAlFondoDeUnaPila(pila5,10)
# Out:
# [10, 1, 2, 3, 4]<->

# %% [markdown]
# ### **Ejercicio 6**
#
# Escribir una función que elimine de una pila todas las ocurrencias de un elemento dado. Usar una pila auxiliar.

# %%
def eliminarOcurrencias(unaPila:Pila , unElementoAEliminar:int)->None: #Declaro mi función que recibe una pila y un elemento a eliminar
  pilaAux = Pila() #Declaro mi pila auxiliar
  while not unaPila.estaVacia(): #Mientras mi pila NO esté vacía
    esteElemento = unaPila.desapilar() #Desapilo. Pero Ojo! Me guardo el dato, porque lo voy a querer procesar. Quiro tomar decisiones mientras recorro
    if esteElemento != unElementoAEliminar: #Si el elemento que desapilé es DISTINTO del elemento a eliminar
      pilaAux.apilar(esteElemento) # apilo el elemento en mi pila auxiliar. Sino, no hago nada
  while not pilaAux.estaVacia(): #Ahora en pila auxiliar tengo solo los elementos que me interesan, así que desapilo y lo guardo como siempre. Mientras pila auxiliar NO esté vacía
    unaPila.apilar(pilaAux.desapilar()) #Apilo en mi pila los elementos que voy desapilando de la pila auxiliar, que solo contiene los datos que me interesan

miPila = Pila([1 , 2 , 3 , 4 , 5 , 5 , 4 , 3 , 2 , 1])
print(miPila)
eliminarOcurrencias(miPila , 3)
print(miPila)

# %% [markdown]
# ### **Ejercicio 7**
#
# Escribir un función que duplique el contenido de una pila.
#
# Por ejemplo, si la pila de entrada es:
#
# Pila = 8, 5, 6, 9
#
# Luego de la función la salida debe ser:
#
# pilaSalida = 8, 5, 6, 9, 8, 5, 6, 9

# %%
def duplicarPila(pila):
  pilaAux = pila.clonar()
  invertirPila(pilaAux)
  while not pilaAux.estaVacia():
   pila.apilar(pilaAux.desapilar())
  return pila

miPila = Pila([1 , 2 , 3 , 4 ])
duplicarPila(miPila)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]<->

# %% [markdown]
# ### **Ejercicio 8**
#
# Escribir una función que realiza el cálculo de la suma de dos números enteros de muchos dígitos (los dos números tienen la misma cantidad de dígitos). La función recibe dos pilas por parámetro, las que almacenan los dígitos de los números a sumar (esta pilas no deben estar modificadas al terminar la función). La función debe retornar una nueva pila con el resultado.
#
# Por ejemplo para sumar: 85699625 + 75426652
#
# Las pilas de entrada a la función son:
#
# Pila1 = 8, 5, 6, 9, 9, 6, 2, 5
#
# Pila2 = 7, 5, 4, 2, 6, 6, 5, 2
#
# La salida:
#
# pilaSalida = 1, 6, 1, 1, 2, 6, 2, 7, 7

# %% [markdown]
# ### **Ejercicio 9**
#
# Escribir la función “reemplazar”, que recibe como parámetro una pila de enteros y dos números enteros: “viejo” y “nuevo”. La función debe modificar la pila ingresada por parámetro, reemplazando cada ocurrencia del número “viejo” por el “nuevo”.

# %%
def reemplazar(unaPila:Pila , unElementoViejo:int , unElementoNuevo)->None: #Declaro mi función que recibe una pila y un elemento a reemplazar: valor viejo (que voy a reemplazar) valor nuevo (que voy a poner)
  pilaAux = Pila() #Declaro mi pila auxiliar
  while not unaPila.estaVacia(): #Mientras mi pila NO esté vacía
    esteElemento = unaPila.desapilar() #Desapilo. Pero Ojo! Me guardo el dato, porque lo voy a querer procesar. Quiro tomar decisiones mientras recorro
    if esteElemento != unElementoViejo: #Si el elemento que desapilé es DISTINTO del elemento a eliminar
      pilaAux.apilar(esteElemento) # apilo el elemento en mi pila auxiliar
    else: #Agrego esta línea, sino, apilo el elemento nuevo
      pilaAux.apilar(unElementoNuevo) #Apilo el elemento nuevo
  while not pilaAux.estaVacia(): #Ahora en pila auxiliar tengo solo los elementos que me interesan, así que desapilo y lo guardo como siempre. Mientras pila auxiliar NO esté vacía
    unaPila.apilar(pilaAux.desapilar()) #Apilo en mi pila los elementos que voy desapilando de la pila auxiliar, que solo contiene los datos que me interesan

miPila = Pila([1 , 2 , 3 , 4 , 5 , 5 , 4 , 3 , 2 , 1])
print(miPila)
reemplazar(miPila , 3 , 700)
print(miPila)

# %% [markdown]
# ### **Ejercicio 10**
#
# Escribir una función que recibe una pila de enteros y retorna dos pilas, una con solo los números pares y otra con solo los impares, provenientes de la pila de entrada. Al finalizar la función, la pila de entrada no debe estar modificada.

# %% [markdown]
# ## **Parte 2: Colas dinámicas**

# %% [markdown]
# ### **Ejercicio 11**
#
# Implementar el TDA Cola (Queue), con las siguientes operaciones:
# - Crear (__init__())
# - Vaciar
# - Encolar elemento (enqueue)
# - Desancolar elemento (dequeue)
# - Obtener primer elemento (top)
# - Obtener tamaño de cola
# - Clonar
# - Esta vacía.
# - __repr__(). Para poder imprimir una Cola por consola

# %%
class Cola:
  def __init__(self):
    self.cola = []

  def tamaño(self)->int:
    return len(self.cola)

  def estaVacia(self)->bool:
    return self.tamaño() == 0

  def encolar(self, dato:int)->None:
    self.cola.append(dato) #Encolando por el final
    #self.cola.insert(0,dato) #Encolando por el inicio

  def tope(self)->int:
    datoCima = None
    if not self.estaVacia():
      datoCima = self.cola[0]  #Desencolo por el inicio
      #datoCima = self.cola[len(self.cola)-1] #Desencolo por el final
    return datoCima

  def desencolar(self)->int:
    dato = None
    if not self.estaVacia():
      dato = self.cola.pop(0)  #Desencolando por el inicio
      #dato = self.cola.pop() #Desencolando por el final
    return dato

  def vaciar(self)->None:
    self.cola = []

  def clonar(self):
    return cp.deepcopy(self)

  def __repr__(self)->str:
    return "<-"+str(self.cola)+"<-"

# %%
cola1 = Cola()
print(cola1)
cola1.encolar(3);cola1.encolar(2);cola1.encolar(7);cola1.encolar(4);
print(cola1)
print(cola1.desencolar())
print(cola1)
cola2 = cola1.clonar()
print("cola2",cola2)
# Out:
# <-[]<-
# <-[3, 2, 7, 4]<-
# 3
# <-[2, 7, 4]<-
# cola2 <-[2, 7, 4]<-

# %% [markdown]
# Iteramos una cola

# %%
#print(cola1)
#while not cola1.estaVacia():
#  print(cola1.desencolar())
#print(cola1)
cola1 = Cola()
cola1.encolar(3);cola1.encolar(2);cola1.encolar(7);cola1.encolar(4);
print(cola1)
for i in range(cola1.tamaño()):
  dato = cola1.desencolar()
  #hacer algo...
  cola1.encolar(dato)
print(cola1)
# Out:
# <-[3, 2, 7, 4]<-
# <-[3, 2, 7, 4]<-

# %% [markdown]
# ### A partir del **Ejercicio 12** vamos a trabajar fuera del TDA Cola usando la interface que creamos en el **Ejercicio 11**. Es decir, se pueden usar solo las operaciones de la interface, no se puede acceder a los componentes internos del TDA. Si necesitan estructuras auxiliares, pueden usar otra cola, pilas, arreglos o listas.

# %% [markdown]
# ### **Ejercicio 12**
#
# Escribir una función que invierta el orden de una cola. No debe devolver una nueva cola invertida, sino invertir la cola que ingresa por parámetro.

# %%
#colaOriginal = <-[2,3,1,5]<-
#cola = <-[5,1,3,2]<-
#pilaAux = []<->

def invertirCola(cola:Cola)->None: #Mi función invertir toma una cola y no devuelve nada, puese modifica la cola ingresada
  pilaAux = Pila() #Instancio una Pila como estructura de datos adiscional
  while not cola.estaVacia(): #Mientras aún haya elementos:
    pilaAux.apilar(cola.desencolar()) #Apilo los elementos que voy sacando de la fila
  while not pilaAux.estaVacia(): #Luego, mientras la pila no esté vacía
    cola.encolar(pilaAux.desapilar()) #Voy desapilando y encolando los elementos. Acá aprovechamos que desapilar ya nos invierte el orden de los elementos.

cola1 = Cola()
cola1.encolar(2);cola1.encolar(3);cola1.encolar(1);cola1.encolar(5);
print(cola1)
invertirCola(cola1)
print(cola1)
# Out:
# <-[2, 3, 1, 5]<-
# <-[5, 1, 3, 2]<-

# %% [markdown]
# ### **Ejercicio 13**
#
# Escribir una función que extraiga el primer elemento de una cola y lo ponga en el final, respetando el orden del resto de los elementos.

# %%
#Cola original = <-[2, 3, 1, 5]<-
#Cola original = <-[3, 1, 5, 2]<-

def primeroEnElFinal1(cola): #Defino mi funión que pone el primer elemento en el final
  primerElemento = cola.desencolar() #Desencolo el primer elemento y me lo guardo en una variable
  cola.encolar(primerElemento) #Encolo el elemento que guardé, siendo ahora el último
  return(cola) #Retorno el mismo elemento de entrada pero transformado

def primeroEnElFinal2(cola): #Otra forma de verlo más compacto
  cola.encolar(cola.desencolar()) #Directamente en una línea encolo el elemento que desencolé
  return cola

cola1 = Cola()
cola1.encolar(2);cola1.encolar(3);cola1.encolar(1);cola1.encolar(5);
print(cola1)
print(primeroEnElFinal1(cola1))
print(cola1)
print(primeroEnElFinal2(cola1))
print(cola1)
# Out:
# <-[2, 3, 1, 5]<-
# <-[3, 1, 5, 2]<-
# <-[3, 1, 5, 2]<-
# <-[1, 5, 2, 3]<-
# <-[1, 5, 2, 3]<-

# %% [markdown]
# ### **Ejercicio 14**
#
# Escribir una función que coloque en el principio de una cola un nuevo elemento.

# %%
def insertarAlPrincipio(unElemento:int , cola:Cola): #Defino mi función que toma un elemento y lo inserta al principio
  invertirCola(cola)
  cola.encolar(unElemento)
  invertirCola(cola)

cola1 = Cola()
cola1.encolar(2);cola1.encolar(3);cola1.encolar(1);cola1.encolar(5);
print(cola1)
print(insertarAlPrincipio(56 , cola1))
print(cola1)
# Out:
# <-[2, 3, 1, 5]<-
# None
# <-[56, 2, 3, 1, 5]<-

# %% [markdown]
# ### **Ejercicio 15**
#
# Escribir una función que elimine de una cola todas las ocurrencias de un elemento dado.

# %%
def eliminarDato(cola, dato): #Definimos nuestra función que toma una fila, un dato y no devuelve nada pues es el mismo objeto transformado
  for i in range(cola.tamaño()): #Para cada índice en mi rango de elementos que compnen la fila
    num = cola.desencolar() #Guardo el elemento que desencolo en una variable llamada num
    if num != dato: #Si el elemento es distinto que el dato que estoy buscando
      cola.encolar(num) #Vuelvo a encolarlo

c1 = Cola()
c1.encolar(1);c1.encolar(3);c1.encolar(2);c1.encolar(5);c1.encolar(4);c1.encolar(2);c1.encolar(3);c1.encolar(4);
print(c1)
eliminarDato(c1,2)
print(c1)

# %% [markdown]
# ### **Ejercicio 16**
#
# Escribir una función que recibe una cola de enteros y genera dos colas: una con los números primos y otra con los números no primos, de la cola de entrada. Al terminar la función, la cola de entrada no debe estar modificada.

# %%
def esPrimo(num): #Primero defino mi función "esPrimo" que toma un número
  if num == 2:
    return True
  for n in range(2,num):
    if num % n == 0:
      return False
    return True


def separaPrimos(cola:Cola)->tuple[Cola,Cola]:
  colaAux = cola.clonar()
  colaPrimos = Cola()
  colaCompuestos = Cola()
  while not colaAux.estaVacia():
    dato = colaAux.desencolar()
    if esPrimo(dato):
      colaPrimos.encolar(dato)
    else:
      colaCompuestos.encolar(dato)
  return colaPrimos,colaCompuestos

c1 = Cola()
c1.encolar(1);c1.encolar(3);c1.encolar(2);c1.encolar(5);c1.encolar(4);c1.encolar(2);c1.encolar(3);c1.encolar(4);
print(c1)
print(separaPrimos(c1))

# %% [markdown]
# ### **Ejercicio 17**
#
# Implementar la función "mezcla" de dos colas, que recibe como parámetros dos colas ordenadas de menor a mayor y devuelve una nueva cola con la unión de ambas colas de entrada con sus elementos ordenados de la misma manera.

# %% [markdown]
# ### **Ejercicio 18**
#
# Implementar la función que recibe como parámetro una cola y elimina todos los números pares.

# %%
def eliminarElementoPares(unaCola):
  colaAux = Cola()
  while not unaCola.estaVacia():
    if unaCola.tope() % 2 == 0:
      unaCola.desencolar()
    else:
      colaAux.encolar(unaCola.desencolar())
  while not colaAux.estaVacia():
    unaCola.encolar(colaAux.desencolar())
  return unaCola

c2 = Cola()
c1.encolar(2);c1.encolar(3);c1.encolar(7);c1.encolar(9);c1.encolar(12);c1.encolar(15);
print(eliminarElementoPares(c2))

# %%
def esMayor(numero , otronumero):
  if numero > otronumero :
    numero = numero
  else :
    numero = otronumero
  return numero

print(esMayor(5,None))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-346ad5ec4172> in <cell line: 0>()
#       6   return numero
#       7
# ----> 8 print(esMayor(5,None))
#
# <ipython-input-6-346ad5ec4172> in esMayor(numero, otronumero)
#       1 def esMayor(numero , otronumero):
# ----> 2   if numero > otronumero :
#       3     numero = numero
#       4   else :
#       5     numero = otronumero
#
# TypeError: '>' not supported between instances of 'int' and 'NoneType'
